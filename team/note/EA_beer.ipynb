# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
beer =pd.read_csv("../Data/beer_data_set.csv")
beer.head()
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# 0       25       50  ...    32        9      47     74    33      0      33
# 1       25       50  ...    57       18      33     55    16      0      24
# 2       25       50  ...    37        6      42     43    11      0      10
# 3       25       50  ...    55       31      47    101    18      1      49
# 4       25       50  ...    69       10      63    120    14      0      19
#
#    Hoppy  Spices  Malty
# 0     57       8    111
# 1     35      12     84
# 2     54       4     62
# 3     40      16    119
# 4     36      15    218
#
# [5 rows x 21 columns]

# %%
beer.describe()
# Out:
#                key    Style Key         ABV   Ave Rating      Min IBU  \
# count  5558.000000  5558.000000  5558.00000  5558.000000  5558.000000
# mean   2779.500000    64.449082     6.63373     3.760239    20.715545
# std    1604.600729    35.814930     2.52166     0.442951    13.736873
# min       1.000000     2.000000     0.00000     1.270000     0.000000
# 25%    1390.250000    34.000000     5.00000     3.590000    10.000000
# 50%    2779.500000    64.000000     6.00000     3.820000    20.000000
# 75%    4168.750000    95.000000     7.90000     4.040000    25.000000
# max    5558.000000   126.000000    57.50000     4.830000    65.000000
#
#            Max IBU  Astringency         Body      Alcohol       Bitter  \
# count  5558.000000  5558.000000  5558.000000  5558.000000  5558.000000
# mean     38.452321    15.938647    42.746132    15.975171    34.316121
# std      22.184524    11.624254    28.589959    18.268342    27.118100
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      25.000000     8.000000    25.000000     5.000000    13.000000
# 50%      35.000000    14.000000    38.000000    10.000000    29.000000
# 75%      45.000000    22.000000    55.000000    20.000000    51.000000
# max     100.000000    83.000000   197.000000   139.000000   150.000000
#
#              Sweet         Sour        Salty       Fruits        Hoppy  \
# count  5558.000000  5558.000000  5558.000000  5558.000000  5558.000000
# mean     53.629723    34.610291     1.314142    39.378553    38.414538
# std      35.866101    39.850228     3.874110    36.652293    31.912843
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      27.000000     9.000000     0.000000    10.000000    14.000000
# 50%      49.500000    21.000000     0.000000    28.000000    30.000000
# 75%      74.000000    44.000000     1.000000    61.750000    56.000000
# max     263.000000   323.000000    66.000000   222.000000   193.000000
#
#             Spices        Malty
# count  5558.000000  5558.000000
# mean     17.584023    68.591400
# std      23.973879    44.600385
# min       0.000000     0.000000
# 25%       4.000000    33.000000
# 50%       9.000000    65.000000
# 75%      22.000000    99.000000
# max     184.000000   304.000000

# %%
beer.isnull().sum()
# Out:
# Name           2
# key            0
# Style          0
# Style Key      0
# Brewery        0
# Description    0
# ABV            0
# Ave Rating     0
# Min IBU        0
# Max IBU        0
# Astringency    0
# Body           0
# Alcohol        0
# Bitter         0
# Sweet          0
# Sour           0
# Salty          0
# Fruits         0
# Hoppy          0
# Spices         0
# Malty          0
# dtype: int64

# %%
na_beer = beer.dropna(how='any')

# %%
na_beer.isnull().sum()
# Out:
# Name           0
# key            0
# Style          0
# Style Key      0
# Brewery        0
# Description    0
# ABV            0
# Ave Rating     0
# Min IBU        0
# Max IBU        0
# Astringency    0
# Body           0
# Alcohol        0
# Bitter         0
# Sweet          0
# Sour           0
# Salty          0
# Fruits         0
# Hoppy          0
# Spices         0
# Malty          0
# dtype: int64

# %%
len(beer)
# Out:
# 5558

# %%
na_beer
# Out:
#                                              Name  key          Style  \
# 0                                           Amber  251        Altbier
# 1                                      Double Bag  252        Altbier
# 2                                  Long Trail Ale  253        Altbier
# 3                                    Doppelsticke  254        Altbier
# 4                                          Scurry  255        Altbier
# ...                                           ...  ...            ...
# 5553                          Red Nose Winter Ale  696  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  697  Winter Warmer
# 5555                         Fish Tale Winterfish  698  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  699  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  700  Winter Warmer
#
#       Style Key                                  Brewery  \
# 0             8                      Alaskan Brewing Co.
# 1             8                   Long Trail Brewing Co.
# 2             8                   Long Trail Brewing Co.
# 3             8           Uerige Obergärige Hausbrauerei
# 4             8                        Off Color Brewing
# ...         ...                                      ...
# 5553         17         Natty Greene's Pub & Brewing Co.
# 5554         17                   Anchor Brewing Company
# 5555         17  Fish Brewing Company / Fishbowl Brewpub
# 5556         17                  Shmaltz Brewing Company
# 5557         17                     Hoppin' Frog Brewery
#
#                                             Description  ABV  Ave Rating  \
# 0     Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1     Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2     Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                                Notes:  8.5        4.15
# 4     Notes:Just cause it's dark and German doesn't ...  5.3        3.67
# ...                                                 ...  ...         ...
# 5553                                             Notes:  6.8        3.59
# 5554  Notes:This is the forty-fifth annual Our Speci...  6.9        3.79
# 5555                                             Notes:  7.5        3.76
# 5556  Notes:Chanukah Beer pours a rich crystal clear...  8.0        3.61
# 5557  Notes:The essence of Christmas is captured in ...  8.6        3.89
#
#       Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  \
# 0          25       50  ...    32        9      47     74    33      0
# 1          25       50  ...    57       18      33     55    16      0
# 2          25       50  ...    37        6      42     43    11      0
# 3          25       50  ...    55       31      47    101    18      1
# 4          25       50  ...    69       10      63    120    14      0
# ...       ...      ...  ...   ...      ...     ...    ...   ...    ...
# 5553       35       50  ...    44       24      19     52    21      0
# 5554       35       50  ...    73        9      58     87    23      0
# 5555       35       50  ...    36       50      70     72    59      0
# 5556       35       50  ...    64       30      57     78    15      1
# 5557       35       50  ...    50       49      13     71    17      0
#
#       Fruits  Hoppy  Spices  Malty
# 0         33     57       8    111
# 1         24     35      12     84
# 2         10     54       4     62
# 3         49     40      16    119
# 4         19     36      15    218
# ...      ...    ...     ...    ...
# 5553      26     21      96     77
# 5554      48     91      44    104
# 5555      81    110      18     73
# 5556      28     57      23    129
# 5557      33     16     148     69
#
# [5556 rows x 21 columns]

# %%
na_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5556 entries, 0 to 5557
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5556 non-null   object
#  1   key          5556 non-null   int64
#  2   Style        5556 non-null   object
#  3   Style Key    5556 non-null   int64
#  4   Brewery      5556 non-null   object
#  5   Description  5556 non-null   object
#  6   ABV          5556 non-null   float64
#  7   Ave Rating   5556 non-null   float64
#  8   Min IBU      5556 non-null   int64
#  9   Max IBU      5556 non-null   int64
#  10  Astringency  5556 non-null   int64
#  11  Body         5556 non-null   int64
#  12  Alcohol      5556 non-null   int64
#  13  Bitter       5556 non-null   int64
#  14  Sweet        5556 non-null   int64
#  15  Sour         5556 non-null   int64
#  16  Salty        5556 non-null   int64
#  17  Fruits       5556 non-null   int64
#  18  Hoppy        5556 non-null   int64
#  19  Spices       5556 non-null   int64
#  20  Malty        5556 non-null   int64
# dtypes: float64(2), int64(15), object(4)
# memory usage: 954.9+ KB

# %%
na_beer.shape
# Out:
# (5556, 21)

# %%
beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5558 entries, 0 to 5557
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5556 non-null   object
#  1   key          5558 non-null   int64
#  2   Style        5558 non-null   object
#  3   Style Key    5558 non-null   int64
#  4   Brewery      5558 non-null   object
#  5   Description  5558 non-null   object
#  6   ABV          5558 non-null   float64
#  7   Ave Rating   5558 non-null   float64
#  8   Min IBU      5558 non-null   int64
#  9   Max IBU      5558 non-null   int64
#  10  Astringency  5558 non-null   int64
#  11  Body         5558 non-null   int64
#  12  Alcohol      5558 non-null   int64
#  13  Bitter       5558 non-null   int64
#  14  Sweet        5558 non-null   int64
#  15  Sour         5558 non-null   int64
#  16  Salty        5558 non-null   int64
#  17  Fruits       5558 non-null   int64
#  18  Hoppy        5558 non-null   int64
#  19  Spices       5558 non-null   int64
#  20  Malty        5558 non-null   int64
# dtypes: float64(2), int64(15), object(4)
# memory usage: 912.0+ KB

# %%
len(na_beer.Style.unique())
# Out:
# 112

# %%
# na_beer.set_index('Style', inplace=True)
# na_beer.head()

# %%
beer1 = na_beer.loc[:,['Style','ABV','Ave Rating','Min IBU','Max IBU','Astringency','Body','Alcohol','Bitter','Sweet','Sour','Salty','Fruits','Hoppy','Spices','Malty']]
beer1
# Out:
#               Style  ABV  Ave Rating  Min IBU  Max IBU  Astringency  Body  \
# 0           Altbier  5.3        3.65       25       50           13    32
# 1           Altbier  7.2        3.90       25       50           12    57
# 2           Altbier  5.0        3.58       25       50           14    37
# 3           Altbier  8.5        4.15       25       50           13    55
# 4           Altbier  5.3        3.67       25       50           21    69
# ...             ...  ...         ...      ...      ...          ...   ...
# 5553  Winter Warmer  6.8        3.59       35       50            8    44
# 5554  Winter Warmer  6.9        3.79       35       50           22    73
# 5555  Winter Warmer  7.5        3.76       35       50           11    36
# 5556  Winter Warmer  8.0        3.61       35       50            6    64
# 5557  Winter Warmer  8.6        3.89       35       50            8    50
#
#       Alcohol  Bitter  Sweet  Sour  Salty  Fruits  Hoppy  Spices  Malty
# 0           9      47     74    33      0      33     57       8    111
# 1          18      33     55    16      0      24     35      12     84
# 2           6      42     43    11      0      10     54       4     62
# 3          31      47    101    18      1      49     40      16    119
# 4          10      63    120    14      0      19     36      15    218
# ...       ...     ...    ...   ...    ...     ...    ...     ...    ...
# 5553       24      19     52    21      0      26     21      96     77
# 5554        9      58     87    23      0      48     91      44    104
# 5555       50      70     72    59      0      81    110      18     73
# 5556       30      57     78    15      1      28     57      23    129
# 5557       49      13     71    17      0      33     16     148     69
#
# [5556 rows x 16 columns]

# %% [markdown]
# ---
# # 시각화요!!!

# %%
beer1_pair = beer1[['ABV','Ave Rating','Min IBU','Max IBU','Astringency','Body','Alcohol','Bitter','Sweet','Sour','Salty','Fruits','Hoppy','Spices','Malty']]
# Basic correlogram
for i in range(3):
    sns.pairplot(beer1_pair.iloc[:,(i*5):(i*5)+5])

# %%
import seaborn as sns

sns.heatmap(beer1.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score # 교차검증

# %%
max_k_range =beer1.shape[0] 
max_k_range
# Out:
# 5556

# %%
beer1.keys()
# Out:
# Index(['Style', 'ABV', 'Ave Rating', 'Min IBU', 'Max IBU', 'Astringency',
#        'Body', 'Alcohol', 'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits',
#        'Hoppy', 'Spices', 'Malty'],
#       dtype='object')

# %%
csv_data = beer1[['ABV', 'Ave Rating', 'Min IBU', 'Max IBU', 'Astringency','Body', 'Alcohol', 'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits','Hoppy', 'Spices', 'Malty']]
csv_label =beer1['Style']

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_label, test_label = train_test_split(
    csv_data, csv_label
)

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
nn_clf = KNeighborsClassifier(n_neighbors=3) #n_neighbors=3 :하이퍼 파라미터라고한다. 데이터가 많은때는 줄이고, 적을때는 올린다.
nn_clf.fit(train_data,train_label)
print("KNN train :",nn_clf.score(train_data,train_label))
print("KNN test :",nn_clf.score(test_data,test_label))
print('-' * 30)

# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_clf =DecisionTreeClassifier()
dt_clf.fit(train_data,train_label)
print("Decision Tree train :", dt_clf.score(train_data,train_label))
print("Decision Tree test :", dt_clf.score(test_data,test_label))
print('-' * 30)

# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier()
rf_clf.fit(train_data,train_label)
print("Random Forest train :", rf_clf.score(train_data,train_label))
print("Random Forest test :", rf_clf.score(test_data,test_label))
print('-' * 30)

# AdaBoost
from sklearn.ensemble import AdaBoostClassifier
ad_clf =AdaBoostClassifier()
ad_clf.fit(train_data,train_label)
print("AdaBoost train :", ad_clf.score(train_data,train_label))
print("AdaBoost test :", ad_clf.score(test_data,test_label))
print('-' * 30)

# Neural Net
from sklearn.neural_network import MLPClassifier
net_clf = MLPClassifier()
net_clf.fit(train_data,train_label)
print("Neural Net train :", net_clf.score(train_data,train_label))
print("Neural Net test :", net_clf.score(test_data,test_label))
print('-' * 30)

# Naive Bayes 
from sklearn.naive_bayes import GaussianNB
nb_clf = GaussianNB()
nb_clf.fit(train_data,train_label)
print("Naive Bayes train :", nb_clf.score(train_data,train_label))
print("Naive Bayes test :", nb_clf.score(test_data,test_label))
print('-' * 30)

# QDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
qda_clf = QuadraticDiscriminantAnalysis()
qda_clf.fit(train_data,train_label)
print("QDA train :", qda_clf.score(train_data,train_label))
print("QDA test :", qda_clf.score(test_data,test_label))
print('-' * 30)
# Out:
# KNN train : 0.67170626349892
# KNN test : 0.4348452123830094
# ------------------------------
# Decision Tree train : 1.0
# Decision Tree test : 0.7897768178545717
# ------------------------------
# Random Forest train : 1.0
# Random Forest test : 0.8358531317494601
# ------------------------------
# AdaBoost train : 0.17782577393808496
# AdaBoost test : 0.1490280777537797
# ------------------------------
# Neural Net train : 0.9431245500359972
# Neural Net test : 0.7177825773938085
# ------------------------------
# Naive Bayes train : 0.8540916726661867
# Naive Bayes test : 0.8200143988480921
# ------------------------------
# QDA train : 0.6671466282697385
# QDA test : 0.6472282217422606
# ------------------------------
# /Users/tj/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/tj/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:808: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %% [markdown]
# > 모든 모델의 train점수가 test의 점수보다 잘 나와서 과대 적합이다.
